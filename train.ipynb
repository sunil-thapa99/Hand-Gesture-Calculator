# %%
import numpy as np
import cv2
import os
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Activation, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd
import imutils
from imutils.contours import sort_contours

# %%
x = []
y = []
datadir = 'dataset'
for folder in os.listdir(datadir):
    path = os.path.join(datadir, folder)
    for images in os.listdir(path):
        img = cv2.imread(os.path.join(path, images))
        x.append(img)
        y.append(folder)
        
print(len(x))
print(len(y))
print(f'labels : {list(set(y))}')
# Out:
# ['div', 'mul', '9', '0', '7', '6', '1', '8', 'sub', 'add', '4', '3', '2', '5']
# 7600
# 7600
# labels : ['8', '3', 'div', '6', '7', 'mul', '4', '5', '9', 'sub', 'add', '1', '0', '2']

# %%
figure = plt.figure(figsize=(10, 10))
j = 0
for i in list(set(y)):
    idx = y.index(i)
    img = x[idx]
    img = cv2.resize(img, (256, 256))
    figure.add_subplot(5, 5, j+1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(i)
    j += 1

# %%
unique, count = np.unique(y, return_counts=True)
figure = plt.figure(figsize=(20, 10))
sn.barplot(x=unique, y=count).set_title('Number of Images per Category')
plt.show()

# %%
X = []
for i in range(len(x)):
#     print(i)
    img = x[i]
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    threshold_image = cv2.threshold(img_gray, 0, 255, cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)[1]
    threshold_image = cv2.resize(threshold_image, (32, 32))
    X.append(threshold_image)
print(len(X))
# Out:
# 7600

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
print(len(y))
# Out:
# 7600

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)

# %%
unique_train, count_train = np.unique(Y_train, return_counts=True)
figure = plt.figure(figsize=(20, 10))
sn.barplot(x=unique_train, y=count_train).set_title('Number of Images per category in Train Set')
plt.show()

# %%
unique_test, count_test = np.unique(Y_test, return_counts=True)
figure = plt.figure(figsize=(20, 10))
sn.barplot(x=unique_test, y=count_test).set_title('Number of Images per category in Test Set')
plt.show()

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)
X_train = X_train/255.
X_test = X_test/255.

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (6080, 32, 32, 1)
# (1520, 32, 32, 1)
# (6080, 14)
# (1520, 14)

# %%
def math_symbol_and_digits_recognition(input_shape=(32, 32, 1)):
    regularizer = l2(0.01)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), strides=(1, 1), padding='same', 
                     kernel_initializer=glorot_uniform(seed=0), 
                     name='conv1', activity_regularizer=regularizer))
    model.add(Activation(activation='relu', name='act1'))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(32, (3, 3), strides=(1, 1), padding='same', 
                     kernel_initializer=glorot_uniform(seed=0), 
                     name='conv2', activity_regularizer=regularizer))
    model.add(Activation(activation='relu', name='act2'))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same', 
                     kernel_initializer=glorot_uniform(seed=0), 
                     name='conv3', activity_regularizer=regularizer))
    model.add(Activation(activation='relu', name='act3'))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(120, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dense(84, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dense(14, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    
    optimizer = Adam()
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
model = math_symbol_and_digits_recognition(input_shape=(32, 32, 1))
model.summary()
# Out:
# 2022-11-29 14:11:30.714049: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-29 14:11:30.715034: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        320
#
#  act1 (Activation)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2 (Conv2D)              (None, 16, 16, 32)        9248
#
#  act2 (Activation)           (None, 16, 16, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv3 (Conv2D)              (None, 8, 8, 64)          18496
#
#  act3 (Activation)           (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 120)               123000
#
#  fc2 (Dense)                 (None, 84)                10164
#
#  fc3 (Dense)                 (None, 14)                1190
#
# =================================================================
# Total params: 162,418
# Trainable params: 162,418
# Non-trainable params: 0
# _________________________________________________________________

# %%
def step_decay(epoch):
    initial_learning_rate = 0.001
    dropEvery = 10
    factor = 0.5
    lr = initial_learning_rate*(factor**np.floor((1 + epoch)/dropEvery))
    return float(lr)

checkpoint = ModelCheckpoint('maths_symbol_and_digits_recognition.h5', 
                             monitor='val_loss', save_best_only=True, 
                             verbose=1, mode='min')

callbacks = [checkpoint, LearningRateScheduler(step_decay)]

# %%
aug = ImageDataGenerator(zoom_range=0.1,
                         rotation_range=5,
                         width_shift_range=0.05,
                         height_shift_range=0.05)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=100, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 2022-11-29 14:12:05.355897: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-11-29 14:12:05.833918: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - ETA: 0s - loss: 2.7668 - accuracy: 0.2396
# 2022-11-29 14:12:11.406586: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 6s 46ms/step - loss: 2.7668 - accuracy: 0.2396 - val_loss: 2.1960 - val_accuracy: 0.4750
# Epoch 2/100
# 48/48 [==============================] - 2s 34ms/step - loss: 1.7189 - accuracy: 0.5669 - val_loss: 1.4388 - val_accuracy: 0.7105
# Epoch 3/100
# 48/48 [==============================] - 2s 34ms/step - loss: 1.1971 - accuracy: 0.7000 - val_loss: 1.1687 - val_accuracy: 0.7322
# Epoch 4/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.9400 - accuracy: 0.7780 - val_loss: 0.9017 - val_accuracy: 0.8250
# Epoch 5/100
# 48/48 [==============================] - 2s 31ms/step - loss: 0.8247 - accuracy: 0.8058 - val_loss: 1.0352 - val_accuracy: 0.7553
# Epoch 6/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.7269 - accuracy: 0.8342 - val_loss: 1.0557 - val_accuracy: 0.7408
# Epoch 7/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.6592 - accuracy: 0.8531 - val_loss: 0.8790 - val_accuracy: 0.8026
# Epoch 8/100
# 48/48 [==============================] - 2s 37ms/step - loss: 0.5616 - accuracy: 0.8806 - val_loss: 0.9537 - val_accuracy: 0.7697
# Epoch 9/100
# 48/48 [==============================] - 2s 31ms/step - loss: 0.5186 - accuracy: 0.8934 - val_loss: 0.7632 - val_accuracy: 0.8184
# Epoch 10/100
# 48/48 [==============================] - 1s 31ms/step - loss: 0.5187 - accuracy: 0.8854 - val_loss: 0.6244 - val_accuracy: 0.8836
# Epoch 11/100
# 48/48 [==============================] - 2s 31ms/step - loss: 0.4696 - accuracy: 0.9074 - val_loss: 0.9719 - val_accuracy: 0.7566
# Epoch 12/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0
100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1333 - accuracy: 0.9724 - val_loss: 0.1952 - val_accuracy: 0.9684
# Epoch 58/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1344 - accuracy: 0.9735 - val_loss: 0.1755 - val_accuracy: 0.9730
# Epoch 59/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1258 - accuracy: 0.9773 - val_loss: 0.1864 - val_accuracy: 0.9664
# Epoch 60/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1259 - accuracy: 0.9762 - val_loss: 0.1539 - val_accuracy: 0.9796
# Epoch 61/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1237 - accuracy: 0.9755 - val_loss: 0.3015 - val_accuracy: 0.9230
# Epoch 62/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1230 - accuracy: 0.9747 - val_loss: 0.2056 - val_accuracy: 0.9625
# Epoch 63/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1289 - accuracy: 0.9753 - val_loss: 0.1978 - val_accuracy: 0.9638
# Epoch 64/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1112 - accuracy: 0.9803 - val_loss: 0.1513 - val_accuracy: 0.9757
# Epoch 65/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1305 - accuracy: 0.9745 - val_loss: 0.1397 - val_accuracy: 0.9816
# Epoch 66/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1168 - accuracy: 0.9776 - val_loss: 0.1717 - val_accuracy: 0.9711
# Epoch 67/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1101 - accuracy: 0.9808 - val_loss: 0.1668 - val_accuracy: 0.9737
# Epoch 68/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1411 - accuracy: 0.9688 - val_loss: 0.2106 - val_accuracy: 0.9579
# Epoch 69/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1404 - accuracy: 0.9720 - val_loss: 0.2971 - val_accuracy: 0.9382
# Epoch 70/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1263 - accuracy: 0.9771 - val_loss: 0.1595 - val_accuracy: 0.9776
# Epoch 71/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1193 - accuracy: 0.9762 - val_loss: 0.1536 - val_accuracy: 0.9783
# Epoch 72/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1012 - accuracy: 0.9842 - val_loss: 0.1645 - val_accuracy: 0.9737
# Epoch 73/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0949 - accuracy: 0.9836 - val_loss: 0.1384 - val_accuracy: 0.9803
# Epoch 74/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0993 - accuracy: 0.9804 - val_loss: 0.1414 - val_accuracy: 0.9816
# Epoch 75/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1201 - accuracy: 0.9752 - val_loss: 0.1806 - val_accuracy: 0.9697
# Epoch 76/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1020 - accuracy: 0.9834 - val_loss: 0.1583 - val_accuracy: 0.9770
# Epoch 77/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1024 - accuracy: 0.9811 - val_loss: 0.1548 - val_accuracy: 0.9743
# Epoch 78/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1083 - accuracy: 0.9808 - val_loss: 0.1236 - val_accuracy: 0.9849
# Epoch 79/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1106 - accuracy: 0.9778 - val_loss: 0.1534 - val_accuracy: 0.9783
# Epoch 80/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0973 - accuracy: 0.9817 - val_loss: 0.1616 - val_accuracy: 0.9776
# Epoch 81/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0984 - accuracy: 0.9834 - val_loss: 0.1335 - val_accuracy: 0.9829
# Epoch 82/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0909 - accuracy: 0.9840 - val_loss: 0.1310 - val_accuracy: 0.9842
# Epoch 83/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1045 - accuracy: 0.9789 - val_loss: 0.1462 - val_accuracy: 0.9770
# Epoch 84/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1002 - accuracy: 0.9826 - val_loss: 0.1298 - val_accuracy: 0.9836
# Epoch 85/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0991 - accuracy: 0.9824 - val_loss: 0.1625 - val_accuracy: 0.9743
# Epoch 86/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0928 - accuracy: 0.9844 - val_loss: 0.1552 - val_accuracy: 0.9724
# Epoch 87/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0966 - accuracy: 0.9816 - val_loss: 0.1761 - val_accuracy: 0.9684
# Epoch 88/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1046 - accuracy: 0.9794 - val_loss: 0.1358 - val_accuracy: 0.9789
# Epoch 89/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0940 - accuracy: 0.9824 - val_loss: 0.1319 - val_accuracy: 0.9842
# Epoch 90/100
# 48/48 [==============================] - 2s 34ms/step - loss: 0.0966 - accuracy: 0.9821 - val_loss: 0.1427 - val_accuracy: 0.9789
# Epoch 91/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0891 - accuracy: 0.9839 - val_loss: 0.1270 - val_accuracy: 0.9849
# Epoch 92/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0991 - accuracy: 0.9799 - val_loss: 0.1393 - val_accuracy: 0.9783
# Epoch 93/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.1011 - accuracy: 0.9829 - val_loss: 0.1342 - val_accuracy: 0.9842
# Epoch 94/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0897 - accuracy: 0.9852 - val_loss: 0.1243 - val_accuracy: 0.9842
# Epoch 95/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0794 - accuracy: 0.9868 - val_loss: 0.1488 - val_accuracy: 0.9770
# Epoch 96/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0779 - accuracy: 0.9872 - val_loss: 0.1181 - val_accuracy: 0.9789
# Epoch 97/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0796 - accuracy: 0.9872 - val_loss: 0.1330 - val_accuracy: 0.9803
# Epoch 98/100
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0998 - accuracy: 0.9786 - val_loss: 0.1488 - val_accuracy: 0.9770
# Epoch 99/100
# 48/48 [==============================] - 2s 32ms/step - loss: 0.0946 - accuracy: 0.9831 - val_loss: 0.2180 - val_accuracy: 0.9520
# Epoch 100/100
# 48/48 [==============================] - 2s 34ms/step - loss: 0.0921 - accuracy: 0.9822 - val_loss: 0.1335 - val_accuracy: 0.9803

# %%
figure = plt.figure(figsize=(5, 5))
plt.plot(hist.history['accuracy'], label='Train Set Accuracy')
plt.plot(hist.history['val_accuracy'], label='Test Set Accuracy')
plt.title('Accuracy Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
plt.plot(hist.history['loss'], label='Train Set Loss')
plt.plot(hist.history['val_loss'], label='Test Set Loss')
plt.title('Loss Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend(loc='upper right')
plt.show()

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_hat = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_hat, ypred))
# Out:
# 48/48 [==============================] - 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96       126
#            1       0.99      0.96      0.98       114
#            2       1.00      1.00      1.00        90
#            3       0.98      0.99      0.99       121
#            4       0.95      0.95      0.95        97
#            5       1.00      0.94      0.97        81
#            6       0.96      0.97      0.96       112
#            7       0.99      1.00      0.99        96
#            8       0.94      0.98      0.96       111
#            9       0.94      0.99      0.96       111
#           10       1.00      0.99      1.00       122
#           11       1.00      1.00      1.00        90
#           12       0.99      1.00      1.00       122
#           13       1.00      1.00      1.00       127
#
#     accuracy                           0.98      1520
#    macro avg       0.98      0.98      0.98      1520
# weighted avg       0.98      0.98      0.98      1520

# %%
model.save('digit_model.h5')
